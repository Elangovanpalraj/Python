# %%
class cardio:
    def __init__(self):
        print("welcome to cardio")
    def patient(self):
        self.docter=("go to psycatrist")
class psycatrist:
    def __init__(self):
        super().patient()
        print("welcome to psycatrist")
obj=psycatrist()
dc = cardio()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 10
#       8         super().patient()
#       9         print("welcome to psycatrist")
# ---> 10 obj=psycatrist()
#      11 dc = cardio()
#
# Cell In[5], line 8, in psycatrist.__init__(self)
#       7 def __init__(self):
# ----> 8     super().patient()
#       9     print("welcome to psycatrist")
#
# AttributeError: 'super' object has no attribute 'patient'

# %%
class cardio:
    def __init__(self):
        print("welcome to cardio")
    def patient(self):
        self.docter=("go to psycatrist")
class psycatrist:
    def __init__(self):
        super().patient()
        print("welcome to psycatrist")
obj=psycatrist()
dc = cardio()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 10
#       8         super().patient()
#       9         print("welcome to psycatrist")
# ---> 10 obj=psycatrist()
#      11 dc = cardio()
#
# Cell In[5], line 8, in psycatrist.__init__(self)
#       7 def __init__(self):
# ----> 8     super().patient()
#       9     print("welcome to psycatrist")
#
# AttributeError: 'super' object has no attribute 'patient'

# %%
class cardio:
    def __init__(self):
        print("welcome to cardio")
    def patient(self):
        self.docter=("go to psycatrist")
class psycatrist:
    def __init__(self):
        super().patient()
        print("welcome to psycatrist")
obj=psycatrist()
dc = cardio()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 10
#       8         super().patient()
#       9         print("welcome to psycatrist")
# ---> 10 obj=psycatrist()
#      11 dc = cardio()
#
# Cell In[5], line 8, in psycatrist.__init__(self)
#       7 def __init__(self):
# ----> 8     super().patient()
#       9     print("welcome to psycatrist")
#
# AttributeError: 'super' object has no attribute 'patient'

# %%
class cardio:
    def __init__(self):
        print("welcome to cardio")
    def patient(self):
        self.docter=("go to psycatrist")
class psycatrist:
    def __init__(self):
        super().patient()
        print("welcome to psycatrist")
obj=psycatrist()
dc = cardio()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 10
#       8         super().patient()
#       9         print("welcome to psycatrist")
# ---> 10 obj=psycatrist()
#      11 dc = cardio()
#
# Cell In[5], line 8, in psycatrist.__init__(self)
#       7 def __init__(self):
# ----> 8     super().patient()
#       9     print("welcome to psycatrist")
#
# AttributeError: 'super' object has no attribute 'patient'
