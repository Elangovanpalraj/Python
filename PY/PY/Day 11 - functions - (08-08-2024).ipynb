# %%
def add():
    a=6
    b=4
    print(a+b)
add()
# Out:
# 10

# %%
def add():
    a=5
    b=6
    return(a+b)
add()
# Out:
# 11

# %%
#return +-*/
#print+-*/
#take 4 variables
#ansnwer should be same
def add():
    a=2
    b=3
    print(a+b)
add()
# Out:
# 5

# %%
def sub():
    a=2
    b=3
    print(a-b)
sub()
# Out:
# -1

# %%
def mul():
    a=2
    b=3
    print(a*b)
mul()
# Out:
# 6

# %%
def div():
    a=2
    b=3
    print(a/b)
div()
# Out:
# 0.6666666666666666

# %%
def add():
    a=2
    b=3
    return(a+b)
add()
# Out:
# 5

# %%
def sub():
    a=2
    b=3
    return(a-b)
sub()
# Out:
# -1

# %%
def mul():
    a=2
    b=3
    return(a*b)
mul()
# Out:
# 6

# %%
def div():
    a=2
    b=3
    return(a/b)
div()
# Out:
# 0.6666666666666666

# %%
def add(h,j): #parameter
    return h+j
print(add(7,8)) #argument
print(add(9,8))
# Out:
# 15
# 17

# %%
def add(c,d,e,f):
    return(c+d+e+f)
print(add(2,3,4,5))
# Out:
# 14
