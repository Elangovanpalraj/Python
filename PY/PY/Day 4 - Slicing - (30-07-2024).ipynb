# %%
b='dharshini'

# %%
b[-3::-1]
# Out:
# 'ihsrahd'

# %%
0,1,2,3,

# %%
-1,-2,

# %%
a={'a':1,'b':2}
a['a']=5
a['b']=10
a
# Out:
# {'a': 5, 'b': 10}

# %%
a=[1,2,3,4,5,6,7]
print(a[-1::-1])     #[start:stop:step] =>step helps in skipping the no of elements in between the elements
# Out:
# [7, 6, 5, 4, 3, 2, 1]

# %%
a=[1,2,3,4,5,6,7]
print(a[-1:-6:-1])
# Out:
# [7, 6, 5, 4, 3]

# %%
a=[1,2,3,4,5,6,7]
print(a[-1:-6:-2])
# Out:
# [7, 5, 3]

# %%
a=[1,2,3,4,5,6,7]
print(a[1:5])      #[start:stop]
# Out:
# [2, 3, 4, 5]

# %%
a=[1,2,3,4,5,6,7]
print(a[-1:-6:-3])
# Out:
# [7, 4]
