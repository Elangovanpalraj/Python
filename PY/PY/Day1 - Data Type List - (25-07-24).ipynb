# %%
f_list=["apple","orenge","banana","cherry"]
print(type(f_list))
# Out:
# <class 'list'>

# %%
f_list.append("grapes")
print(f_list)
# Out:
# ['apple', 'orenge', 'banana', 'cherry', 'grapes']

# %%
f_list.remove("apple")
print(f_list)
# Out:
# ['orenge', 'banana', 'cherry', 'grapes']

# %%
print(len(f_list))
# Out:
# 4

# %%
print(f_list[2])
# Out:
# cherry

# %%
f_list.insert(2,"gova")
print(f_list)
# Out:
# ['orenge', 'banana', 'gova', 'cherry', 'grapes']

# %%
f_list1=f_list.copy()
print(f_list1)
# Out:
# ['orenge', 'banana', 'gova', 'cherry', 'grapes']

# %%
f_list2=[]
f_list2=f_list1
print(f_list2)
# Out:
# ['orenge', 'banana', 'gova', 'cherry', 'grapes']

# %%
f_list2.insert(3,False)
print(f_list2)
# Out:
# ['orenge', 'banana', 'gova', False, 'cherry', 'grapes']

# %%
f_list2.insert(4,True)
print(f_list2)
# Out:
# ['orenge', 'banana', 'gova', False, True, 'cherry', 'grapes']

# %%
f_list2.index('gova')
print(f_list2)
# Out:
# ['orenge', 'banana', 'gova', False, True, 'cherry', 'grapes']

# %%
f_list.pop()
# Out:
# 'grapes'

# %%
f_list2.pop(6)
# Out:
# 'grapes'

# %%
f_list2.pop()
# Out:
# 'cherry'

# %%
f_list2.index(False)
print(f_list2)

# %%
f_list2.reverse()
print(f_list2)
# Out:
# [True, False, 'gova', 'banana', 'orenge']

# %%
f_list.sort()
print(f_list)
# Out:
# ['banana', 'cherry', 'gova', 'orenge']

# %%
f_list.sort(reverse=True)
print(f_list)
# Out:
# ['orenge', 'gova', 'cherry', 'banana']

# %%
f_list.index("cherry")
# Out:
# 2

# %%
f_list.index("gova")
# Out:
# 1

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']
