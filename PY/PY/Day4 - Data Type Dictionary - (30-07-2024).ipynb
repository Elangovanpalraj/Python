# %%
dict1={
    'a':1,
    'b':2
}
dict2={
    'a':4,
    'd':1
}
dict1.update(dict2)
dict1
# Out:
# {'a': 4, 'b': 2, 'd': 1}

# %%
dict1={
    'a':1,
    'b':2
}
dict2={
    'a':4,
    'd':1
}
dict3=dict1.copy()
dict3
# Out:
# {'a': 1, 'b': 2}

# %%
a=('a','b','c')
b=5
dict_3=dict.fromkeys(a,b)
dict_3
# Out:
# {'a': 5, 'b': 5, 'c': 5}

# %%
k={}
a=('a','b','c')
b=[5,4,5]
dict3=k.fromkeys(a,b)
k
# Out:
# {}

# %%
k=('q','w','e')
z=258
dict9=dict.fromkeys(k,z)
dict9
# Out:
# {'q': 258, 'w': 258, 'e': 258}

# %%
a={'a':1,'b':2}
b=a.setdefault('c',3)
a
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
a={'a':1,'b':2}
b=a.setdefault('b',3)
a
# Out:
# {'a': 1, 'b': 2}

# %%
b
# Out:
# 2

# %%
a.values()
# Out:
# dict_values([1, 2])
