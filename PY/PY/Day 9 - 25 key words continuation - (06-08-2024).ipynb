# %%
a="hello world!"
a.startswith("h")
# Out:
# True

# %%
a.endswith("!")
# Out:
# True

# %%
a=["apple","grapes","avacado"]
for i in a:
    if i.startswith("a"):
        print(i)
# Out:
# apple
# avacado

# %%
a=["apple","grapes","avacado"]
for i in a:
    if i.endswith("e"):
        print(i)
# Out:
# apple

# %%
# replace
a="hello world"

# %%
a.replace("hello","python")
a
# Out:
# 'hello world'

# %%
a="hello world"
a.replace("e","a")
# Out:
# 'hallo world'

# %%
a
# Out:
# 'hello world'

# %%
a=range(1,10)
shelly=[]
for i in a:
    i=str(i)
    i=i.replace("5","7")
    i=int(i)
    print(i)
    if i%3==0:
        shelly.append(i)
# Out:
# 1
# 2
# 3
# 4
# 7
# 6
# 7
# 8
# 9

# %%
shelly
for i in shelly:
    i=str(i)
    i=i.replace("6","7")
    i=int(i)
    print(i)
# Out:
# 3
# 7
# 9

# %%
a="1 2 3"
a.isdigit()
# Out:
# False

# %%
a="chennai 600070"
b=""
for i in a:
    if i.isdigit():
     print(i)
     b+=i
# Out:
# 6
# 0
# 0
# 0
# 7
# 0

# %%
b
# Out:
# '600070'

# %%
"45 roses and 23 lilly"
