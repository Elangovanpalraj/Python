# %%
#british airlines
    #place 
    #time
    #display seat
    #booking seat
    #payment
    #cancellation
    #refund
class british_airlines:
    def __init__(self):
        print("welcome to british airlines")
        available_options=["place","time","display seat","booking seat","payment","cancellation","refund"]
        Available_options={"place":f"enter the 'place' below",
        "for time":f"enter the 'time' below",
        "for display seat":f"enter the 'display seat' below",
        "for booking seat":f"enter the 'booking seat' below",
        "for payment":f"enter the 'payment' below",
        "for cancellation":f"enter the 'cancellation' below",
        "for refund":f"enter the 'refund' below"}
        for i in Available_options.items():
            print(i)
        self.selectedplace=input("enter the place").lower()
        
        while self.selectedplace not in self.place:
            if selected in available_options:
                pass
            else:
                selected=input("enter the option")
                print("thanks for choosing. If valid we  will proceed next")
    def place(self):
        print("chose the below place to go: ")
        self.place=['banglore','goa','russia','spain','argentina']
        for i in self.place():
            print(i)
        self.ticket_price={
            'banglore':1200,
            'goa':5000,
            'russia':75000,
            'spain':60000,
            'argentina':35000
        }
        for ticket in ticket_price:
            print(ticket)
        self.place("enter the place")
        if self.place in self.ticket_price:
            print(self.ticket_price[self.place})
        
airlines=british_airlines()
airlines.place()
# Out:
# welcome to british airlines
# ('place', "enter the 'place' below")
# ('for time', "enter the 'time' below")
# ('for display seat', "enter the 'display seat' below")
# ('for booking seat', "enter the 'booking seat' below")
# ('for payment', "enter the 'payment' below")
# ('for cancellation', "enter the 'cancellation' below")
# ('for refund', "enter the 'refund' below")
# enter the place xmkxa
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 46
#      43             print(ticket)
#      44         self.place("enter the place")
# ---> 46 airlines=british_airlines()
#      47 airlines.place()
#
# Cell In[46], line 24, in british_airlines.__init__(self)
#      21     print(i)
#      22 self.selectedplace=input("enter the place").lower()
# ---> 24 while self.selectedplace not in self.place:
#      25     if selected in available_options:
#      26         pass
#
# TypeError: argument of type 'method' is not iterable

# %%
seat=range(1,50)

# %%
a="Yellow"
y=input()
if a.lower()==y.lower():
    print("pass")
# Out:
#  Yellow
# pass
