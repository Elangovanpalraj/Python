# %%
num=int(input("enter a number"))
if num%2==0:
    print(f"the num is divisible by 2")
else:
    print(f"the num is not divisible by 2")
# Out:
# enter a number 4
# the num is divisible by 2

# %%
num=0
for i in range(1,51):
    if i%2==0:
        num+=i
print(num)
# Out:
# 650

# %%
a=[1,3,4,26,13]
num=0
for i in a:
    if i%2==0:
        num+=i
print(num)
# Out:
# 30

# %%
a="python program"
print(a[2:6])
# Out:
# thon

# %%
num=int(input("enter a number"))
if num%2==0 or num%3==0:
    print(f"the num is {num} divisible by 2 or 3")
else:
    print(f"the num is {num} not divisible by 2 or 3")
# Out:
# enter a number 12
# the num is 12 divisible by 2 or 3

# %%
name=["abishek","abi","arun","antony"]
new=[]
for i in name:
    if i.startswith("ab"):
        new.append(i)
print(new)
# Out:
# ['abishek', 'abi']

# %%
num=int(input("enter the number:"))
for i in range(2,num):
    if num%i==0:
        print(f"the number is {num} is not prime number")
        break
    else:
        print(f"the number is {num} is prime number")
# Out:
# enter the number: 4
# the number is 4 is not prime number

# %%
num=0
for i in range(1,31):
    if i%2!=0:
        num+=i
print(num)
# Out:
# 225

# %%
a=("him","her","they","them")
for i in a:
    print(i.capitalize(),end=" ")
# Out:
# Him Her They Them

# %%
a={1,2,3,4}
a.add(5)
print(a)
# Out:
# {1, 2, 3, 4, 5}

# %%
num=[13,56,101,245,387,45]
for i in num:
    if i>100:
        continue
    print(i)
# Out:
# 13
# 56
# 45

# %%
num=[13,56,245,101,387,45]
for i in num:
    if i>100:
        break
print(i)
# Out:
# 245

# %%
a=[13,56,245,101,387,45]
a.sort()
for i in a:
    if i>100:
        break
print(i)
# Out:
# 101

# %%
a=[13,56,245,101,387,45]
a.sort()
for i in a:
    if i<100:
        break
print(i)
# Out:
# 13

# %%
cars_garage = {
    "Tata": {"Model": "Suv", "seats": 4,"windows":5,"tyres":4},
    "Hundai": {"Model": "Verina", "seats": 5,"windows":4,"tyres":4},
    "Ford ": {"Model": "mustang", "seats": 4,"windows":6,"tyres":4},
    "Benz": {"Model": "AMG", "seats": 5,"windows":6,"tyres":4},
    "BMW": {"Model": "Version", "seats": 6,"windows":5,"tyres":4},
    "Audi": {"Model": "sportback", "seats": 5,"windows":5,"tyres":4},
    "Mercedes-Benz": {"Model": "Sedan", "seats": 5,"windows":3,"tyres":4},
    "Volkswagen": {"Model": "Hatchback", "seats": 5,"windows":6,"tyres":4},
    "Suzuki": {"Model": "etron", "seats": 5,"windows":5,"tyres":4},
    "Renault-Nissan": {"Model": "punch", "seats": 5,"windows":4,"tyres":4},
    "Ambasedar": {"Model": "old", "seats": 5,"windows":6,"tyres":4},
    "Jaquar": {"Model": "fire", "seats": 5,"windows":4,"tyres":4},
    "Nano": {"Model": "lite", "seats": 7,"windows":4,"tyres":4},
    "Kia": {"Model": "range", "seats": 5,"windows":5,"tyres":4},
    "Jeep": {"Model": "bullet", "seats": 4,"windows":4,"tyres":4},
    "Rolls-Royce": {"Model": "A4", "seats": 5,"windows":4,"tyres":4},
    "Volvo": {"Model": "V3", "seats": 7,"windows":6,"tyres":4},
    "Tesla": {"Model": "Elonmusk", "seats": 4,"windows":3,"tyres":4},
    "Honda": {"Model": "hero", "seats": 5,"windows":6,"tyres":4},
    "Toyato": {"Model": "range", "seats": 7,"windows":5,"tyres":4},
    "Bollero": {"Model": "A1", "seats": 7,"windows":4,"tyres":4},
    "Scarpio": {"Model": "D1", "seats": 7,"windows":4,"tyres":4},
    "Ferrari": {"Model": "fast", "seats": 5,"windows":4,"tyres":4},
    "Porsche": {"Model": "P4", "seats": 4,"windows":6,"tyres":4},
    "Xiaomi": {"Model": "MI", "seats": 5,"windows":5,"tyres":4}
}

print(cars_garage)
# Out:
# {'Tata': {'Model': 'Suv', 'seats': 4, 'windows': 5, 'tyres': 4}, 'Hundai': {'Model': 'Verina', 'seats': 5, 'windows': 4, 'tyres': 4}, 'Ford ': {'Model': 'mustang', 'seats': 4, 'windows': 6, 'tyres': 4}, 'Benz': {'Model': 'AMG', 'seats': 5, 'windows': 6, 'tyres': 4}, 'BMW': {'Model': 'Version', 'seats': 6, 'windows': 5, 'tyres': 4}, 'Audi': {'Model': 'sportback', 'seats': 5, 'windows': 5, 'tyres': 4}, 'Mercedes-Benz': {'Model': 'Sedan', 'seats': 5, 'windows': 3, 'tyres': 4}, 'Volkswagen': {'Model': 'Hatchback', 'seats': 5, 'windows': 6, 'tyres': 4}, 'Suzuki': {'Model': 'etron', 'seats': 5, 'windows': 5, 'tyres': 4}, 'Renault-Nissan': {'Model': 'punch', 'seats': 5, 'windows': 4, 'tyres': 4}, 'Ambasedar': {'Model': 'old', 'seats': 5, 'windows': 6, 'tyres': 4}, 'Jaquar': {'Model': 'fire', 'seats': 5, 'windows': 4, 'tyres': 4}, 'Nano': {'Model': 'lite', 'seats': 7, 'windows': 4, 'tyres': 4}, 'Kia': {'Model': 'range', 'seats': 5, 'windows': 5, 'tyres': 4}, 'Jeep': {'Model': 'bullet', 'seat
# ...

# %%
dict.keys(cars_garage)
# Out:
# dict_keys(['Tata', 'Hundai', 'Ford ', 'Benz', 'BMW', 'Audi', 'Mercedes-Benz', 'Volkswagen', 'Suzuki', 'Renault-Nissan', 'Ambasedar', 'Jaquar', 'Nano', 'Kia', 'Jeep', 'Rolls-Royce', 'Volvo', 'Tesla', 'Honda', 'Toyato', 'Bollero', 'Scarpio', 'Ferrari', 'Porsche', 'Xiaomi'])

# %%
list(cars_garage.items())
# Out:
# [('Tata', {'Model': 'Suv', 'seats': 4, 'windows': 5, 'tyres': 4}),
#  ('Hundai', {'Model': 'Verina', 'seats': 5, 'windows': 4, 'tyres': 4}),
#  ('Ford ', {'Model': 'mustang', 'seats': 4, 'windows': 6, 'tyres': 4}),
#  ('Benz', {'Model': 'AMG', 'seats': 5, 'windows': 6, 'tyres': 4}),
#  ('BMW', {'Model': 'Version', 'seats': 6, 'windows': 5, 'tyres': 4}),
#  ('Audi', {'Model': 'sportback', 'seats': 5, 'windows': 5, 'tyres': 4}),
#  ('Mercedes-Benz', {'Model': 'Sedan', 'seats': 5, 'windows': 3, 'tyres': 4}),
#  ('Volkswagen', {'Model': 'Hatchback', 'seats': 5, 'windows': 6, 'tyres': 4}),
#  ('Suzuki', {'Model': 'etron', 'seats': 5, 'windows': 5, 'tyres': 4}),
#  ('Renault-Nissan', {'Model': 'punch', 'seats': 5, 'windows': 4, 'tyres': 4}),
#  ('Ambasedar', {'Model': 'old', 'seats': 5, 'windows': 6, 'tyres': 4}),
#  ('Jaquar', {'Model': 'fire', 'seats': 5, 'windows': 4, 'tyres': 4}),
#  ('Nano', {'Model': 'lite', 'seats': 7, 'windows': 4, 'tyres': 4}),
# ...

# %%
dict.values(cars_garage)
# Out:
# dict_values([{'Model': 'Suv', 'seats': 4, 'windows': 5, 'tyres': 4}, {'Model': 'Verina', 'seats': 5, 'windows': 4, 'tyres': 4}, {'Model': 'mustang', 'seats': 4, 'windows': 6, 'tyres': 4}, {'Model': 'AMG', 'seats': 5, 'windows': 6, 'tyres': 4}, {'Model': 'Version', 'seats': 6, 'windows': 5, 'tyres': 4}, {'Model': 'sportback', 'seats': 5, 'windows': 5, 'tyres': 4}, {'Model': 'Sedan', 'seats': 5, 'windows': 3, 'tyres': 4}, {'Model': 'Hatchback', 'seats': 5, 'windows': 6, 'tyres': 4}, {'Model': 'etron', 'seats': 5, 'windows': 5, 'tyres': 4}, {'Model': 'punch', 'seats': 5, 'windows': 4, 'tyres': 4}, {'Model': 'old', 'seats': 5, 'windows': 6, 'tyres': 4}, {'Model': 'fire', 'seats': 5, 'windows': 4, 'tyres': 4}, {'Model': 'lite', 'seats': 7, 'windows': 4, 'tyres': 4}, {'Model': 'range', 'seats': 5, 'windows': 5, 'tyres': 4}, {'Model': 'bullet', 'seats': 4, 'windows': 4, 'tyres': 4}, {'Model': 'A4', 'seats': 5, 'windows': 4, 'tyres': 4}, {'Model': 'V3', 'seats': 7, 'windows': 6, 'tyres': 4},
# ...

# %%
seats_values=[car["seats"] for car in cars_garage.values()]
print(seats_values)
# Out:
# [4, 5, 4, 5, 6, 5, 5, 5, 5, 5, 5, 5, 7, 5, 4, 5, 7, 4, 5, 7, 7, 7, 5, 4, 5]

# %%
Model_values=[car["Model"] for car in cars_garage.values()]
print(Model_values)
# Out:
# ['Suv', 'Verina', 'mustang', 'AMG', 'Version', 'sportback', 'Sedan', 'Hatchback', 'etron', 'punch', 'old', 'fire', 'lite', 'range', 'bullet', 'A4', 'V3', 'Elonmusk', 'hero', 'range', 'A1', 'D1', 'fast', 'P4', 'MI']

# %%
tyres_values=[car["tyres"] for car in cars_garage.values()]
print(tyres_values)
# Out:
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]

# %%
windows_values=[car["windows"] for car in cars_garage.values()]
print(windows_values)
# Out:
# [5, 4, 6, 6, 5, 5, 3, 6, 5, 4, 6, 4, 4, 5, 4, 4, 6, 3, 6, 5, 4, 4, 4, 6, 5]

# %%
windows=list(set(windows_values))               #values to denoted to set and list
print(windows)
# Out:
# [3, 4, 5, 6]

# %%
tyres=list(set(tyres_values))                #type casting
print(tyres)
# Out:
# [4]

# %%
models=list(set(Model_values))
print(models)
# Out:
# ['Hatchback', 'Suv', 'V3', 'D1', 'punch', 'AMG', 'range', 'fire', 'P4', 'Elonmusk', 'sportback', 'A1', 'bullet', 'Verina', 'lite', 'Version', 'etron', 'old', 'hero', 'mustang', 'A4', 'Sedan', 'MI', 'fast']

# %%
seats=list(set(seats_values))
print(seats)
# Out:
# [4, 5, 6, 7]

# %%
nethaji=170
gandiji=14
gnanavel=24
sakthi=30

if nethaji >sakthi  and nethaji >gnanavel and nethaji >gandiji:
    print('nethaji older')
else:
    print('younger')
# Out:
# nethaji older

# %%
bjp=240
congress=270
if bjp > congress:
    print(f"the winner of election is {bjp} and is bjp.")
elif congress > bjp:
    print(f"the winner of election is {congress} and is congress.")
else:
    print("the  election is tie")
# Out:
# the winner of election is 270 and is congress.

# %%
days=7
i=1
total=0
while i<=days:
    cal=float(input(f"enter a days{i} :"))
    total+=cal
    average=total/days
    i+=1
print(total)
print(average)
# Out:
# enter a days1 : 5
# enter a days2 : 5
# enter a days3 : 5
# enter a days4 : 5
# enter a days5 : 5
# enter a days6 : 5
# enter a days7 : 5
# 35.0
# 5.0

# %%
natural_numbers=[]
n=int(input("enter a number:"))
for i in range (1,n+1):
    natural_numbers.append(i)
    
print(f"the {n} natural is {natural_numbers}")
# Out:
# enter a number: 5
# the 5 natural is [1, 2, 3, 4, 5]

# %%
cube=int(input("enter a number:"))
for i in range(1,10):
    print(f"the cube {i} is :")
    print(i*i*i)
# Out:
# enter a number: 5
# the cube 1 is :
# 1
# the cube 2 is :
# 8
# the cube 3 is :
# 27
# the cube 4 is :
# 64
# the cube 5 is :
# 125
# the cube 6 is :
# 216
# the cube 7 is :
# 343
# the cube 8 is :
# 512
# the cube 9 is :
# 729
