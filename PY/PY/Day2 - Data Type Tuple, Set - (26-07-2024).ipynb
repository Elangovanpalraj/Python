# %%
tup=(1,2,3,4,5)
print(type(tup))
# Out:
# <class 'tuple'>

# %%
tup.count(1)
# Out:
# 1

# %%
tup.index(5)
# Out:
# 4

# %%
set1={1,1,2,3,0.1}
set1
# Out:
# {0.1, 1, 2, 3}

# %%
print(type(set1))
# Out:
# <class 'set'>

# %%
print(type(tup[0]))
# Out:
# <class 'int'>

# %%
set1={1,1,2,3,0.1,"ram"}
set1
# Out:
# {0.1, 1, 2, 3, 'ram'}

# %%
bag={"rice1kg","suger","rice500g","rice500g"}
print(bag)
# Out:
# {'rice1kg', 'rice500g', 'suger'}

# %%
bag={"red ball","yellow ball","green ball","redball","blue ball",1,2,1,0,0.3}
bag
# Out:
# {0, 0.3, 1, 2, 'blue ball', 'green ball', 'red ball', 'redball', 'yellow ball'}

# %%
bag.add("salt")
bag
# Out:
# {0,
#  0.3,
#  1,
#  2,
#  'blue ball',
#  'green ball',
#  'red ball',
#  'redball',
#  'salt',
#  'yellow ball'}

# %%
bag.remove("salt")
bag
# Out:
# {0, 0.3, 1, 2, 'blue ball', 'green ball', 'red ball', 'redball', 'yellow ball'}

# %%
bag.pop()    # dont use pop as u dont know which element will get deleted
bag
# Out:
# {0.3, 1, 2, 'blue ball', 'green ball', 'red ball', 'redball', 'yellow ball'}

# %%
bag.clear()
bag
# Out:
# set()

# %%
bag={"rice1kg","suger","rice500g","rice500g"}
bag
# Out:
# {'rice1kg', 'rice500g', 'suger'}

# %%
bag=list(bag)
bag
# Out:
# ['rice1kg', 'rice500g', 'suger']

# %%
a=[1,1,2,2,3,3]
a
# Out:
# [1, 1, 2, 2, 3, 3]

# %%
a=set(a)
a
# Out:
# {1, 2, 3}

# %%
a=list(a)
a
# Out:
# [1, 2, 3]

# %%
a=1,2,3
a
# Out:
# (1, 2, 3)

# %%
type(a)
# Out:
# tuple

# %%
bag
# Out:
# ['rice1kg', 'rice500g', 'suger']

# %%
bag=set(bag)
bag
# Out:
# {'rice1kg', 'rice500g', 'suger'}

# %%
no1={1,2,3,4,5}
no2={4,5,6,7,8}
no1.intersection(no2)
# Out:
# {4, 5}

# %%
no1.union(no2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
no1.discard(1)
no1
# Out:
# {2, 3, 4, 5}

# %%
no1.discard(6)
no1
# Out:
# {2, 3, 4, 5}

# %%
no1.remove(6)
no1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 no1.remove(6)
#       2 no1
#
# KeyError: 6

# %%
no1.difference(no2)
# Out:
# {2, 3}

# %%
no1
# Out:
# {2, 3, 4, 5}

# %%
no2
# Out:
# {4, 5, 6, 7, 8}

# %%
no1.update(no2)
no1
# Out:
# {2, 3, 4, 5, 6, 7, 8}

# %%
a=6
b=7
c=a
c
# Out:
# 6

# %%
a=b
a
# Out:
# 7

# %%
b=c
b
# Out:
# 6

# %%
a,b
# Out:
# (7, 6)

# %%
a=1
b=2
a,b=b,a
a,b
# Out:
# (2, 1)

# %%
a=[1,2,3,4,5]
b=a
b
# Out:
# [1, 2, 3, 4, 5]

# %%
b.append(0)
a
# Out:
# [1, 2, 3, 4, 5, 0, 0]
