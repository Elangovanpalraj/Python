# %%
#palindrome
a=input("enter the number")
if a==a[::-1]:
    print("palindrome")
else:
    print("not palinrome")
# Out:
# enter the number madhu
# not palinrome

# %%
pal=input("enter info")
if pal==pal[::-1]:
    print("palinrome")
else:
    print("not a palinrome")
# Out:
# enter info ka
# not a palinrome

# %%
#reverse a word
a="arun"
b=""
for i in a:
    b=i+b
    print(b)
# Out:
# a
# ra
# ura
# nura

# %%
str=input("enter")
b=""
for i in str:
    b=i+b
    print(b)
# Out:
# enter madhan
# m
# am
# dam
# hdam
# ahdam
# nahdam

# %%
#stering handeling
a=("hello everyone, good morning")
a=a.split()
print(a)
# Out:
# ['hello', 'everyone,', 'good', 'morning']

# %%
a=("hello everyone, good morning")
a=a.split("h")
print(a)
# Out:
# ['', 'ello everyone, good morning']

# %%
a=("hello everyone, good morning")
a=a.split("o")
print(a)
# Out:
# ['hell', ' every', 'ne, g', '', 'd m', 'rning']

# %%
a=("hello everyone, good morning")
a=a.split(",")
print(a)
# Out:
# ['hello everyone', ' good morning']

# %%
a=("hello everyone, good morning")
a=a.split("el")
print(a)
# Out:
# ['h', 'lo everyone, good morning']

# %%
a=input("enter")
a=a.split()
print(a)
# Out:
# enter Hi, this is madhuvanthi
# ['Hi,', 'this', 'is', 'madhuvanthi']

# %%
#concatinate
a="hello"
b="world"
c=""
c=a+b
print(c)
# Out:
# helloworld

# %%
#formatting string
name="madhuvathi"
age=23
print("hello my name is",name, "and age is", age)
# Out:
# hello my name is madhuvathi and age is 23

# %%
name="madhuvathi"
age=23
print(f"hello my name is {name} and age is{age}")
# Out:
# hello my name is madhuvathi and age is23

# %%
a="arun"
b="ARUN"
print(a.upper())
print(b.lower())
# Out:
# ARUN
# arun

# %%
a=input("enter name")
b=input("enter name")
if a==b:
    print("equal")
else:
    print("not equal")
if a.upper()==b:
   print("equal")
else:
    print("not equal")
# Out:
# enter name ant
# enter name Ant
# not equal
# not equal

# %%
a=input("enter name")
for i in a:
    i=i.upper()
    print(a.lower())
# Out:
# enter name ant
# ant
# ant
# ant

# %%
a="   hello  "
print(a.strip())
# Out:
# hello

# %%
a="   hello   "
print(a.lstrip())
# Out:
# hello

# %%
a="   hello   "
print(a.rstrip())
# Out:
#    hello

# %%
a="he  llo"
a=a.split()
a
# Out:
# ['he', 'llo']

# %%
a="he  llo"
b=""
a=a.split()
for i in a:
    b+=i
print(b)
# Out:
# hello

# %%
a="he  llo"
a=a.split()
b="".join(a)
print(b)
# Out:
# hello

# %%
a="hello"
b="world"
c=""
c=a.join(b)
print(c)
# Out:
# whelloohellorhellolhellod

# %%
a="AruN"
a=a.swapcase()
print(a)
# Out:
# aRUn

# %%
a="hello im good"
a=a.capitalize()
a
# Out:
# 'Hello im good'

# %%
a="hello im good"
a=a.split()
b=""
for i in a:
    i=i.capitalize()
    b+=i+' '
    print(b)
# Out:
# Hello
# Hello Im
# Hello Im Good
