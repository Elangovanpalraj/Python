# %%
for i in range(1,5):
    print("*"*i)
# Out:
# *
# **
# ***
# ****

# %%
for i in range(5):
    print(" "*(5-i)+"*"*i)
# Out:
#
#     *
#    **
#   ***
#  ****

# %%
for i in range(5):
    print(" "*(5-i)+"* "*i+" "*(5-i))
# Out:
#
#     *
#    * *
#   * * *
#  * * * *

# %%
for i in range(5):
    print(" "*i+"* "*(5-i)+" "*i)
# Out:
# * * * * *
#  * * * *
#   * * *
#    * *
#     *

# %%
for i in range(5):
    print(" "*(5-i)+"* "*i+" "*(5-i))
for i in range(5):
    print(" "*i+"* "*(5-i)+" "*i)
# Out:
#
#     *
#    * *
#   * * *
#  * * * *
# * * * * *
#  * * * *
#   * * *
#    * *
#     *

# %%
a=6
for i in range(1,a):      #1,2,3,4,5
    for j in range(a-i):   #6-1 
        print(" ",end="")
        
    for k in range(i):
        print("*",end="")
    print()
# Out:
#      *
#     **
#    ***
#   ****
#  *****

# %%
row=5
for i in range(1,row):
    for j in range(row-i):
        print(" ",end="")
    for z in range(i):
        print("*",end="")
    print()
# Out:
#     *
#    **
#   ***
#  ****
