# %%
a=('thuit')

# %%
type(a)
# Out:
# str

# %%
age=int(input("enter the age"))
if age>18:
    print("he can vote",age)
else:
    print("he cant able to vote",age)
# Out:
# enter the age 20
# he can vote 20

# %%
age=int(input("enter the age"))
if age>18:
    print("he can vote",age)
else:
    print("he cant able to vote",age)
# Out:
# enter the age 25
# he can vote 25

# %%
age=int(input("enter the age"))
if age>18:
    print("he can vote",age)
elif age<18 and age>0:
    print("he cant able to vote",age)
else:
    print("incorrect age",age)
# Out:
# enter the age -1
# incorrect age -1

# %%
age=int(input("enter the age"))
if age>18:
    print("he can vote",age)
elif age<18 and age>0:
    print("he cant able to vote",age)
else:
    print("incorrect age",age)
# Out:
# enter the age -2
# incorrect age -2

# %%
balance=2000
withdraw=int(input("enter amount"))
if withdraw>2000:
    print("exceding your balance limit",balance)
elif withdraw<2000 and withdraw>0:
    print("amount withdrawn",withdraw)
else:
    print("incorrect input")
# Out:
# enter amount -10000
# incorrect input

# %%
withdraw=int(input("enter the amount"))
balance=int(input("enter the balance"))
if    withdraw<balance:
       print(balance-withdraw)
elif withdraw==balance:
      print(balance-withdraw)
else: print("in sufficient balance")
# Out:
# enter the amount 2500
# enter the balance 2500
# 0
