# %%
def even(a,b):
    for i in range(a,b):
        if i %2==0:
            return i

# %%
a=int(input("enter a no"))
b=int(input("enter a no"))
even(a,b)
# Out:
# enter a no 2
# enter a no 7
# 2

# %%
# a=int(input("enter a no a"))
#b=int(input("enter a no b"))
#c=int(input("enter a no c"))
#d=int(input("enter a no d"))
select_input=["1.add","2.sub","3.divide","4.multiply","5.squire root","6.percentage","7.squire","8.total","9.avg","10.moduli","11.to break"]
def calculator():
    while True:
        for i in select_input:
            print(i)
        enter_ip=int(input("enter number based on above list"))
        if enter_ip==1:
            first=int(input("how many no u want to calculate"))
            count=0
            for i in range(first):
                second=int(input("enter the numbers"))
                count+=count+second-''+'
                print(f"your total count is: {count}, thanks for using")
        elif enter_ip==11:
            print("thankyou for using")
            break
calculator()
# Out:
# 1.add
# 2.sub
# 3.divide
# 4.multiply
# 5.squire root
# 6.percentage
# 7.squire
# 8.total
# 9.avg
# 10.moduli
# 11.to break
# enter number based on above list 1
# how many no u want to calculate 2
# enter the numbers 50
# your total count is: 50, thanks for using
# enter the numbers 20
# your total count is: 120, thanks for using
# 1.add
# 2.sub
# 3.divide
# 4.multiply
# 5.squire root
# 6.percentage
# 7.squire
# 8.total
# 9.avg
# 10.moduli
# 11.to break
# enter number based on above list 11
# thankyou for using
