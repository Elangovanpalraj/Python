# %%
t20=[]

# %%
iplt20=["Rohit Sharma","Hardik Pandya","Yashasvi Jaiswal","Suryakumar Yadav","Rishabh Pant","Sanju Samson","Shivam Dube","Ravindra Jadeja","Axar Patel","Kuldeep Yadav","Yuzvendra Chahal","Arshdeep Singh","Jasprit Bumrah"]
print(iplt20)
# Out:
# ['Rohit Sharma', 'Hardik Pandya', 'Yashasvi Jaiswal', 'Suryakumar Yadav', 'Rishabh Pant', 'Sanju Samson', 'Shivam Dube', 'Ravindra Jadeja', 'Axar Patel', 'Kuldeep Yadav', 'Yuzvendra Chahal', 'Arshdeep Singh', 'Jasprit Bumrah']

# %%
t20=iplt20.copy()
print(t20)
# Out:
# ['Rohit Sharma', 'Hardik Pandya', 'Yashasvi Jaiswal', 'Suryakumar Yadav', 'Rishabh Pant', 'Sanju Samson', 'Shivam Dube', 'Ravindra Jadeja', 'Axar Patel', 'Kuldeep Yadav', 'Yuzvendra Chahal', 'Arshdeep Singh', 'Jasprit Bumrah']

# %%
t20.insert(0,"Virat Kohli")
print(t20)
# Out:
# ['Virat Kohli', 'Rohit Sharma', 'Hardik Pandya', 'Yashasvi Jaiswal', 'Suryakumar Yadav', 'Rishabh Pant', 'Sanju Samson', 'Shivam Dube', 'Ravindra Jadeja', 'Axar Patel', 'Kuldeep Yadav', 'Yuzvendra Chahal', 'Arshdeep Singh', 'Jasprit Bumrah']

# %%
t20.append("MS Dhoni")
t20
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Hardik Pandya',
#  'Yashasvi Jaiswal',
#  'Suryakumar Yadav',
#  'Rishabh Pant',
#  'Sanju Samson',
#  'Shivam Dube',
#  'Ravindra Jadeja',
#  'Axar Patel',
#  'Kuldeep Yadav',
#  'Yuzvendra Chahal',
#  'Arshdeep Singh',
#  'Jasprit Bumrah',
#  'MS Dhoni']

# %%
t20.remove("MS Dhoni")
t20
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Hardik Pandya',
#  'Yashasvi Jaiswal',
#  'Suryakumar Yadav',
#  'Rishabh Pant',
#  'Sanju Samson',
#  'Shivam Dube',
#  'Ravindra Jadeja',
#  'Axar Patel',
#  'Kuldeep Yadav',
#  'Yuzvendra Chahal',
#  'Arshdeep Singh',
#  'Jasprit Bumrah']

# %%
t20.insert(14,"Mohammed Siraj")
t20
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Hardik Pandya',
#  'Yashasvi Jaiswal',
#  'Suryakumar Yadav',
#  'Rishabh Pant',
#  'Sanju Samson',
#  'Shivam Dube',
#  'Ravindra Jadeja',
#  'Axar Patel',
#  'Kuldeep Yadav',
#  'Yuzvendra Chahal',
#  'Arshdeep Singh',
#  'Jasprit Bumrah',
#  'Mohammed Siraj']

# %%
print(len(t20))
# Out:
# 15

# %%
print(t20[6])
# Out:
# Sanju Samson

# %%
t20.insert(16,True)
t20
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Hardik Pandya',
#  'Yashasvi Jaiswal',
#  'Suryakumar Yadav',
#  'Rishabh Pant',
#  'Sanju Samson',
#  'Shivam Dube',
#  'Ravindra Jadeja',
#  'Axar Patel',
#  'Kuldeep Yadav',
#  'Yuzvendra Chahal',
#  'Arshdeep Singh',
#  'Jasprit Bumrah',
#  'Mohammed Siraj',
#  True]

# %%
t20.pop()
# Out:
# True

# %%
t20.reverse()
t20
# Out:
# ['Mohammed Siraj',
#  'Jasprit Bumrah',
#  'Arshdeep Singh',
#  'Yuzvendra Chahal',
#  'Kuldeep Yadav',
#  'Axar Patel',
#  'Ravindra Jadeja',
#  'Shivam Dube',
#  'Sanju Samson',
#  'Rishabh Pant',
#  'Suryakumar Yadav',
#  'Yashasvi Jaiswal',
#  'Hardik Pandya',
#  'Rohit Sharma',
#  'Virat Kohli']

# %%
t20.sort()
t20
# Out:
# ['Arshdeep Singh',
#  'Axar Patel',
#  'Hardik Pandya',
#  'Jasprit Bumrah',
#  'Kuldeep Yadav',
#  'Mohammed Siraj',
#  'Ravindra Jadeja',
#  'Rishabh Pant',
#  'Rohit Sharma',
#  'Sanju Samson',
#  'Shivam Dube',
#  'Suryakumar Yadav',
#  'Virat Kohli',
#  'Yashasvi Jaiswal',
#  'Yuzvendra Chahal']

# %%
t20.sort(reverse=True)
t20
# Out:
# ['Yuzvendra Chahal',
#  'Yashasvi Jaiswal',
#  'Virat Kohli',
#  'Suryakumar Yadav',
#  'Shivam Dube',
#  'Sanju Samson',
#  'Rohit Sharma',
#  'Rishabh Pant',
#  'Ravindra Jadeja',
#  'Mohammed Siraj',
#  'Kuldeep Yadav',
#  'Jasprit Bumrah',
#  'Hardik Pandya',
#  'Axar Patel',
#  'Arshdeep Singh']

# %%
t20.index("Virat Kohli")
# Out:
# 2
