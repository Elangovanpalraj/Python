# %%
a=5
for i in range(a):
    print("*")
# Out:
# *
# *
# *
# *
# *

# %%
a=5
for i in range(a):
    print("*"*a)
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
a=5
for i in range(a):
    print("*"*i)
# Out:
# *
# **
# ***
# ****

# %%
a=5
for i in range(1,a):
    print("*"*i)
# Out:
# *
# **
# ***
# ****

# %%
a=5
for i in range(1,a):
    print(" "*(a-i)+"*"*i)
# Out:
#     *
#    **
#   ***
#  ****

# %%
a=5
for i in range(1,a):
    print(" "*(a-i)+"* "*i+" "*(a-i))
# Out:
#     *
#    * *
#   * * *
#  * * * *
