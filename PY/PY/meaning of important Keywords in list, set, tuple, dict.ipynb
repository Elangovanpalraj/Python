# %%
LIST

# %%
# 1.append: Adds the value in the end of a list. If given as a list then adds as an other list inside te give list.
# 2.remove: Deletes or removes the values from list.
# 3.len: Shows the (length) of the collection of datatype.
# 4.f_list[2]: Gives the index value of the specifies variable.
# 5.insert: Adds the value in a list using index.
# 6.copy: Copies the datatype(list, set, dict or tuple).
# 7.f_list2=f_list1: Copy the dataset without key word. This takes the referrence but dosent save the input.
# 8.index: Shows the index of the value Eg:var.index("values").
# 9.pop: Shows the deleted value of the dataset, generelly deletes the last value of the dataset.
# 10.pop(index): Delets the value given in the mentioned index and Shows the deleted value.
# 11.reverse: Reverses the values in the available dataset.
# 12.sort: Gives the value of the dataset in ascending order. 
# 13.sort(reverse=True) reverse(): Gives the value of the dataset in decending order. 
# 14.clear: Clears the entire values in the dataset
# 15.count: Counts the no of times a value is repeated in a given dataset.
# 16.extend: Adds one argument with multiple value in a dataset. If values given in tuple object every charecter is considered as a seperate value.
# 17.type(var): Shows the class of the datatype.
# 18.typecast: Changes the values of a datatype to another datatype.

# %%
SET

# %%
# 1.add: Add an item to a set
# 2.remove: Deletes or removes the values from set. If value dosent exist in the dataset the keyword gives error.
# 3.pop: Deletes the last value of the dataset and shows the deleted value.We dont use pop in set as this method will remove a random item,
# so we cannot be sure what item gets removed.
# 4.clear:  Clears the entire values in the dataset.Empties the set.
# 5.len: Shows the (length) of the collection of datatype.
# 6.intersection: Gives the similar values of two datasets.
# 7.union: Unites two data sets, keeps the referrence and dosent save the input.
# 8.discard: Deletes or removes the values from set. If value dosent exist in the dataset the keyword will not raise an error.
# 9.difference: Gives a set containing the difference between two or more sets.
# 10.update: To add items from another set into the current set.
# 11.typecast: Changes the values of a datatype to another datatype.
# 12.append: Adds the value in the end of a set. If given as a set then adda as an other set inside te give set.
# 13.del:Delete the set completely.
# 14.copy: Copies the datatype(list, set, dict or tuple).

# %%
TUPLE

# %%
# 1.typecast: Changes the values of a datatype to another datatype.
# 2.count: Counts the no of times a value is repeated in a given dataset.
# 3.index: Shows the index of the value Eg:var.index("values").
# 4.copy: Copies the data type(list, set, dict or tuple).

# %%
DICT

# %%
# 1.keys: Gives a list of all the keys in the dictionary
# 2.values: Gives a list of all the values in the dictionary
# 3.items: Gives a list of each key value pair in the dictionary
# 4.add: Dict object has no attribute add
# 5.get: Gives the value of the specified key
# 6.update: Updates the dictionary with the specified key-value pairs
# 7.pop: Deletes the element with the specified key and shows the deleted value.
# 8.popitem: Deletes the last inserted key-value pair and shows the deleted key-value pair.
# 9.copy: Copies the datatype(list, set, dict or tuple).
# 10.fromkeys: Gives a dictionary with the specified keys and value.
# 11.setdefault: Gives the existing value of the specified key.If the key does not exist: insert the key, with the specified value
