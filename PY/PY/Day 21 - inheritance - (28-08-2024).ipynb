# %%
class cardio:
    def __init__(self):
        print("welcome to cardio")
    def patient(self):
        self.docter=("go to psycatrist")
class psycatrist:
    def __init__(self):
        super().patient()
        print("welcome to psycatrist")
obj=psycatrist
