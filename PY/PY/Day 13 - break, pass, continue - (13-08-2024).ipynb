# %%
a=[1,2,3,4,5,6,6,7,2,3,3,1]
b=5
for i in a:
    
    if b-i in a:
     print(b-i,i)
# Out:
# 4 1
# 3 2
# 2 3
# 1 4
# 3 2
# 2 3
# 2 3
# 4 1

# %%
#break
#pass
#continue
a=10
for i in range(a):
    print(i)
    if i==5:
        break
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
a=10
for i in range(a):
    if i==5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a=10
for i in range(a):
    pass     #passes the given condition and moves to the next one
print(i)
# Out:
# 9

# %%
a=10
for i in range (a):
    if i==3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5
# 6
# 7
# 8
# 9
