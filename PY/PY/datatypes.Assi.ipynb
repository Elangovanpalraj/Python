# %%
 list=[1,2,3,4,5]
list.append(6)
print(list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list=[1,2,3,4,5]
list.extend([7,8])
list
# Out:
# [1, 2, 3, 4, 5, 7, 8]

# %%
list=[1,2,3,4,5]
list.remove(2)
list
# Out:
# [1, 3, 4, 5]

# %%
list=[1,2,3,4]
list.pop()
list
# Out:
# [1, 2, 3]

# %%
list=[1,2,3,4,5]
list.pop(3)
list
# Out:
# [1, 2, 3, 5]

# %%
list=[1,2,4,5]
list.insert(1,2)
list
# Out:
# [1, 2, 2, 4, 5]

# %%
list=[1,2,3,4,5]
list.index(4)
# Out:
# 3

# %%
list=[1,2,3,3,4,5]
list.count(3)
# Out:
# 2

# %%
list=[2,4,5,1,6]
list.sort()
list
# Out:
# [1, 2, 4, 5, 6]

# %%
list=[1,2,3,4,5]
list.reverse()
list
# Out:
# [5, 4, 3, 2, 1]

# %%
list=[1,2,3,4,5]
list.copy()
list
# Out:
# [1, 2, 3, 4, 5]

# %%
###set methods

# %%
set={1,2,3,4}
set.add(4)
set
# Out:
# {1, 2, 3, 4}

# %%
set1={1,2,3,4}
set2={5,6,7}
set=set1.update(set2)
set1
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
set={1,2,3,4,5}
set.remove(4)
set
# Out:
# {1, 2, 3, 5}

# %%
set={1,2,3,4}
set.discard(5)
set
# Out:
# {1, 2, 3, 4}

# %%
set={1,2,3,4}
set.pop()
# Out:
# 1

# %%
set={1,2,3,4}
set.clear()
set
# Out:
# set()

# %%
set={1,2,3,4}
set.copy()
set
# Out:
# {1, 2, 3, 4}

# %%
a={1,2,3,4}
b={1,2}
a.union(b)
# Out:
# {1, 2, 3, 4}

# %%
a={1,2,3,4}
b={1,2}
a.intersection(b)
# Out:
# {1, 2}

# %%
a={1,2,3,4}
b={1,2}
a.difference(b)
# Out:
# {3, 4}

# %%
####dict

# %%
dict={
    "a":1,
    "b":2
}
dict.clear()
print(dict)
# Out:
# {}

# %%
dict={
    "a":1,
    "b":2
}
dict.copy()
print(dict)
# Out:
# {'a': 1, 'b': 2}

# %%
dict={
    "a":1,
    "b":2
}
dict.get("a")
# Out:
# 1

# %%
dict={
    "a":1,
    "b":2
}
dict.items()
# Out:
# dict_items([('a', 1), ('b', 2)])

# %%
dict={
    "a":1,
    "b":2
}
dict.keys()
# Out:
# dict_keys(['a', 'b'])

# %%
dict={
    "a":1,
    "b":2
}
dict.values()
# Out:
# dict_values([1, 2])

# %%
dict={
    "a":1,
    "b":2
}
dict.pop("a")
# Out:
# 1

# %%
dict={
    "a":1,
    "b":2
}
dict.popitem()
# Out:
# ('b', 2)

# %%
a={"a":1,"b":2}
b={"c":3,"d":4}
a.update(b)
a
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
a={"a":1,"b":1}
a.setdefault("c",3)
a
# Out:
# {'a': 1, 'b': 1, 'c': 3}
