# %%
name_list=["sakthi","ameer","arun","veronica","gnanavel","saran"]
k=list(filter(lambda name_list:name_list.startswith("sa"),name_list))
k
# Out:
# ['sakthi', 'saran']

# %%
k=list(filter(lambda name_list:name_list.endswith("n"),name_list))
k
# Out:
# ['arun', 'saran']

# %%
a=list(map(lambda x:x**2,range(1,10)))
a
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
def even_or_odd(number):
    if number%2==0:
        return "even"
    else:
        return "odd"
number=int(input("enter a number:"))
result=even_or_odd(number)
print(f"{number} is {result}")
# Out:
# enter a number: 15
# 15 is odd

# %%
def palindrome(k):
    k=k.lower()
    return k==k[::-1]
name=input("enter a name:")
result=palindrome(name)
print(f"{name} is a palindrome:{result}")
# Out:
# enter a name: radar
# radar is a palindrome:True

# %%
def prime():
    c=0
    print("enter a number")
    n=int(input())
    for i in range(1,n+1):
       if n%i==0:
          c+=1
    if c==2:
        print(f"{n}  is prime")
    else:
        print(f"{n}  is not prime")
prime()
# Out:
# enter a number
#  84
# 84  is not prime

# %%
def leap_year(year):
    return year%4==0 and (year%100!=0 or year%400==0)
year=int(input("enter a year"))
if leap_year(year):
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# enter a year 2048
# 2048 is a leap year

# %%
#without return
def add(x, y):
    print(f"{x} + {y} = {x + y}")
def subtract(x, y):
    print(f"{x} - {y} = {x - y}")
def multiply(x, y):
    print(f"{x} * {y} = {x * y}")
def divide(x, y):
    print(f"{x} / {y} = {x / y}")
num1 = int(input("enter a num1:"))
num2 = int(input("enter a num2:"))
add(num1, num2)
subtract(num1, num2)
multiply(num1, num2)
divide(num1, num2)
# Out:
# enter a num1: 10
# enter a num2: 5
# 10 + 5 = 15
# 10 - 5 = 5
# 10 * 5 = 50
# 10 / 5 = 2.0

# %%
#with return
def add(x, y):
    return x + y
def subtract(x, y):
    return x - y
def multiply(x, y):
    return x * y
def divide(x, y):
    return x / y
num1 =int(input("enter a num1:"))
num2 =int(input("enter a num2:"))
result_add = add(num1, num2)
result_subtract = subtract(num1, num2)
result_multiply = multiply(num1, num2)
result_divide = divide(num1, num2)
print(f"{num1} + {num2} = {result_add}")
print(f"{num1} - {num2} = {result_subtract}")
print(f"{num1} * {num2} = {result_multiply}")
print(f"{num1} / {num2} = {result_divide}")
# Out:
# enter a num1: 586
# enter a num2: 242
# 586 + 242 = 828
# 586 - 242 = 344
# 586 * 242 = 141812
# 586 / 242 = 2.4214876033057853

# %%
#what is class
#what is object
#what is method
#why we are using return
#why we are using print
#write a code display car details assume like you have25 demo cars and you have to show 6 info about the particular cars
#write a pakistan t20 2024 to show 8 info about the particular players
#why we are using oops concepts and how it is real life projects

# %%
class car_garage:
     def __init__(self):
         self.car_names = ["Toyota","Honda","Ford","Chevrolet","Nissan","BMW 3 Series","Mercedes-Benz","Audi","Volkswagen","Hyundai","Kia","Mazda","Subaru","Lexus","Jaguar","Infiniti","Acura","Cadillac","Chrysler","Dodge","Tesla","Volvo","Alfa Romeo","Genesis","Lincoln"]
         self.tire_types = [4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4]
         self.models = ["Sedan","sports","Coupe","Convertible","SUV","Truck","Hatchback","Minivan","Wagon","Crossover","Electric","Diesel","Hybrid","Luxury","Compact","Subcompact","Roadster","Grand Tourer","Supercar","Off-Road","Performance","City Car","Microcar","Estate","Pickup"]
         self.price = [10000,20000,30000,40000,50000,60000,70000,80000,90000,100000,110000,120000,130000,140000,150000,160000,170000,180000,190000,200000,210000,220000,230000,24000,250000]
         self.user=int(input(f"select the car of your choice,{self.car_names}"))
     def info (self):
          for car in self.car_names:
              return f"car name: {self.car_names[self.user]},tire:{self.tire_types[self.user]},models:{self.models[self.user]}, price:{self.price[self.user]}"
obj=car_garage()
print(obj.info())
# Out:
# select the car of your choice,['Toyota', 'Honda', 'Ford', 'Chevrolet', 'Nissan', 'BMW 3 Series', 'Mercedes-Benz', 'Audi', 'Volkswagen', 'Hyundai', 'Kia', 'Mazda', 'Subaru', 'Lexus', 'Jaguar', 'Infiniti', 'Acura', 'Cadillac', 'Chrysler', 'Dodge', 'Tesla', 'Volvo', 'Alfa Romeo', 'Genesis', 'Lincoln'] 4
# car name: Nissan,tire:4,models:SUV, price:50000

# %%
class Player:
    def __init__(self, name, role, matches, runs, wickets):
        self.name = name
        self.role = role
        self.matches = matches
        self.runs = runs
        self.wickets=wickets
    
    def __str__(self):
        return f"Name: {self.name},\n Role: {self.role}\n matches: {self.matches}\n runs: {self.runs}\n wickets: {self.wickets}"

class PakistanT20Team:
    def __init__(self):
        self.players = []
    
    def add_player(self, player):
        self.players.append(player)
    
    def find_player(self, name):
        for player in self.players:
            if player.name.lower() == name.lower():
                return player
        return None

player1 = Player("Babar Azam", "Batsman", "150" , "3220","0")
player2 = Player("Shadab Khan", "All-rounder", "200", "1000","200")
player3 = Player("Shaheen Afridi", "Bowler", "170", "2100","150")
player4 = Player("M Rizwan", "W-K Batsman", "101" , "3220","0")
player5 = Player("Harris Rauf", "Bowler", "200", "200","190")
player6 = Player("Ifthikar Ahamad", "All-rounder", "170", "2100","70")
player7 = Player("Nassem Shah", "Bowler", "96" , "720","96")
player8 = Player("Fakhar Zaman", "Batsman", "160", "3000","0")
player9 = Player("Hasan ali", "Bowler", "180", "800","150")
player10 = Player("Shoib Malik", "Bowler", "200" , "1000","120")
player11 = Player("Sarfaras Ahamad", "Batsman", "216", "2700","5")

team = PakistanT20Team()
team.add_player(player1)
team.add_player(player2)
team.add_player(player3)
team.add_player(player4)
team.add_player(player5)
team.add_player(player6)
team.add_player(player7)
team.add_player(player8)
team.add_player(player9)
team.add_player(player10)
team.add_player(player11)

player_name = input("Enter player's name: ")

player = team.find_player(player_name)
if player:
    print("\nPlayer career:")
    print(player)
else:
    print("\nPlayer not available in the team.")
# Out:
# Enter player's name:  babar azam
# Player career:
# Name: Babar Azam,
#  Role: Batsman
#  matches: 150
#  runs: 3220
#  wickets: 0

# %%
class banking:
    def __init__(self):
        select_inputs={
            'Balance_enq':'press 1',
            'withdraw' :'press 2',
            'deposit':'press 3',
            'exit':'press 4'
        }
        for inputs in (select_inputs.items()):
            print(inputs)
        # self.user_selected =int(input("enter the number"))
        self.T_Balance=100
    def Balance(self):
        return self.T_Balance
    
    def withdraw(self,withdraw_amt):
        self.T_Balance =self.T_Balance - withdraw_amt
        return self.T_Balance
    def deposit(self,deposit_amt):
        self.T_Balance = self.T_Balance+deposit_amt
        print(self.T_Balance)
obj=banking()
while True:
    user=int(input("enter the number"))
    if user==1:
        print(obj.Balance())
    elif user==2:
        withdraw_amt_enter=int(input("enter the withdraw amt"))
        print(obj.withdraw(withdraw_amt_enter))
    elif user==3:
        deposit_amt =int(input("enter the deposit_amt"))
        obj.deposit(deposit_amt)
        
    else:
        break
# Out:
# ('Balance_enq', 'press 1')
# ('withdraw', 'press 2')
# ('deposit', 'press 3')
# ('exit', 'press 4')
# enter the number 3
# enter the deposit_amt 1000
# 1100
# enter the number 2
# enter the withdraw amt 500
# 600
# enter the number 4

# %%
class Library:
    def __init__(self,list):
        self.books_list = list
        self.available_books_list = list[:]
        self.books_lent = {}
    def display_available_books(self):
        for book in self.available_books_list:
            print(book)
    def display_all_books(self):
        for book in self.books_list:
            print(book)
    def lend_book(self,name,book):
        if book not in self.books_list:
            print("incorrect book name, please check book list:")
            return
        if book in self.available_books_list:
            self.books_lent.update({book:name})
            self.available_books_list.remove(book)
            print("you can take the book")
        else:
            print("the book is already taken by" + self.books_lent[book])
    def return_books(self,book):
        # del self.books_lent[book]
        self.available_books_list.append(book)
lib =["python and ml","artificial intelligence","engineering mechanics","engineering thermodynamics"]
obj=Library(lib)

print("welcome to library,choose book.") 
while True:
        print("1.display available books")
        print("2.display all books")
        print("3.take a book")
        print("4.return a book")
        print("5.quit:")
        user_choice = int(input())
        if user_choice == 1:
            obj.display_available_books()
        elif user_choice == 2:
            obj.display_all_books()
        elif user_choice == 3:
            name = input("enter user name:")
            book = input("enter book name:")
            obj.lend_book(name,book)
        elif user_choice == 4:
            book=input("enter the return book name")
            obj.return_books(book)
        elif user_choice == 5:
            print("thank you")
            break
        else:
            print("invalid choice")
# Out:
# welcome to library,choose book.
# 1.display available books
# 2.display all books
# 3.take a book
# 4.return a book
# 5.quit:
#  1
# python and ml
# artificial intelligence
# engineering mechanics
# engineering thermodynamics
# 1.display available books
# 2.display all books
# 3.take a book
# 4.return a book
# 5.quit:
#  2
# python and ml
# artificial intelligence
# engineering mechanics
# engineering thermodynamics
# 1.display available books
# 2.display all books
# 3.take a book
# 4.return a book
# 5.quit:
#  3
# enter user name: gnanavel
# enter book name: python and ml
# you can take the book
# 1.display available books
# 2.display all books
# 3.take a book
# 4.return a book
# 5.quit:
#  2
# python and ml
# artificial intelligence
# engineering mechanics
# engineering thermodynamics
# 1.display available books
# 2.display all books
# 3.take a book
# 4.return a book
# 5.quit:
#  1
# artificial intelligence
# engineering mechanics
# engineering thermodynamics
# ...

# %%
class Area_Perimeter():
    def calculate_area(self):
        pass
    def calculate_perimeter(self):
        pass
class Rectangle(Area_Perimeter):
    def __init__(self, length, breadth):
        self.length = length
        self.breadth = breadth
    
    def calculate_area(self):
        return self.length * self.breadth
    
    def calculate_perimeter(self):
        return 2 * (self.length + self.breadth)

class Circle(Area_Perimeter):
    def __init__(self, radius):
        self.radius = radius
    
    def calculate_area(self):
        return 3.14 * self.radius ** 2
    
    def calculate_perimeter(self):
        return 2 * 3.14 * self.radius
rectangle = Rectangle(5, 10)
print(f"Rectangle = Area: {rectangle.calculate_area()}, Perimeter: {rectangle.calculate_perimeter()}")

circle = Circle(4)
print(f"Circle = Area: {circle.calculate_area()}, Perimeter: {circle.calculate_perimeter()}")
# Out:
# Rectangle = Area: 50, Perimeter: 30
# Circle = Area: 50.24, Perimeter: 25.12

# %%
class hello:
    def hi(self):
        self.a=6
    def add(self):
        self.b=2
class random(hello):
    def hi(self):
        super().hi()
        super().add()
        print(self.a+self.b)
obj=random()
obj.hi()
# Out:
# 8

# %%
class hello:
    def g(self):
        self.a=7
        super().__init__()
        print(self.b)
class random(hello):
    def __init__(self):
        self.b=9
obj=random()
obj.g()
# Out:
# 9

# %%
a=[1,"z","v","w",8]
ans=""
for i in a:

# %%
a=[1,"z","v","w",8]
a=str(a)
for i in a:
    if i == i.issnumerics():
print(i)
# Out:
#   Cell In[4], line 5
#     print(i)
#             ^
# IndentationError: expected an indented block after 'if' statement on line 4
