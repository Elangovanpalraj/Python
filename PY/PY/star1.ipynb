# %%
n=5
for i in range(1,n+1):
    print("1"*i)
# Out:
# 1
# 11
# 111
# 1111
# 11111

# %%
n=5
for i in range(n,0,-1):
    print("*"*i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
n=5
for i in range(1,n+1):
    print(" "*(n-i)+"* "*i+" "*(n-i))
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *

# %%
n=5
for i in range(n):
    print(" "*i+"* "*(n-i)+" "*i)
# Out:
# * * * * *
#  * * * *
#   * * *
#    * *
#     *

# %%
n=5
for i in range(1,n+1):
    print(" "*(n-i)+"* "*i+" "*(n-i))
for i in range(n):
    print(" "*i+"* "*(n-i)+" "*i)
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *
# * * * * *
#  * * * *
#   * * *
#    * *
#     *

# %%
n=5
for i in range(n):
    print(" "*i+"* "*(n-i)+" "*i)
for i in range(1,n+1):
    print(" "*(n-i)+"* "*i+" "*(n-i))
# Out:
# * * * * *
#  * * * *
#   * * *
#    * *
#     *
#     *
#    * *
#   * * *
#  * * * *
# * * * * *

# %%
n=5
for i in range(1,n+1):
    print(" "*(n-i)+"*"*i)
# Out:
#     *
#    **
#   ***
#  ****
# *****

# %%
n=5
for i in range(n):
    print(" "*i+"*"*(n-i))
# Out:
# *****
#  ****
#   ***
#    **
#     *

# %%
n=5
for i in range(n):
    print("*"*(n-i)+"  "*i+"*"*(n-i))
for i in range(1,n+1):
    print("*"*i+"  "*(n-i)+"*"*i)
# Out:
# **********
# ****  ****
# ***    ***
# **      **
# *        *
# *        *
# **      **
# ***    ***
# ****  ****
# **********

# %%
a=[1,2,3,4,2,3,1,4,3]
b=5
for i in a:
    if b-i in a:
        print(b-i,i)
# Out:
# 4 1
# 3 2
# 2 3
# 1 4
# 3 2
# 2 3
# 4 1
# 1 4
# 2 3

# %%
i=[1,2,24,1,1,1,10,6]
c=1
if 24 in i:
    while c<5:
        print(24)
        c=c+1
# Out:
# 24
# 24
# 24
# 24

# %%
num=int(input("enter a number:"))
factorial=1
num1=1
while num1<=num:
    factorial*=num1
    num1+=1
print(factorial)
# Out:
# enter a number: 5
# 120
