# %%
bjp=240
congress=120
if bjp > congress:
    print(f"the winner of election is {bjp} and is bjp.")
elif congress > bjp:
    print(f"the winner of election is {congress} and is congress.")
else:
    print("the  election is tie")
# Out:
# the winner of election is 240 and is bjp.

# %%
team1="india"
team2="england"
india_score=200
england_score=220
if india_score > england_score:
    print(f"the team {team1} win in the match and go to the final.")
elif england_score > india_score:
    print(f"the team {team2} win in the match and go to the final.")
else:
    print(" the match is abondand due to rain")
# Out:
# the team england win in the match and go to the final.

# %%
team1="brazil"
team2="argentina"
brazil_goals=3
argentina_goals=4
if brazil_goals > argentina_goals:
    print(f"the team {team1} win the match.")
elif argentina_goals > brazil_goals:
    print(f"the team {team2} win the match.")
else:
    print("the match will tie")
# Out:
# the team argentina win the match.

# %%
computer="hp"
ram=11
gb=121
if computer=="hp" and ram>12 and gb>120:
    print(f"the {computer} computer is i7 intel core gen.")
elif computer=="hp" and ram>8 and gb>90:
    print(f"the {computer} computer is i5 intel core gen.")
else:
    print("this is low gen computer")
# Out:
# the hp computer is i5 intel core gen.

# %%
student_name="gnanavel"
mock_marks=81
attendance=95
if mock_marks > 90 and attendance >=95:
    print(f"the student {student_name} is move to the placement.")
elif mock_marks > 80 and attendance >=95:
    print(f"the student {student_name} is consider the trainer.")
else:
    print("there is no consider ,please prepare")
# Out:
# the student gnanavel is consider the trainer.

# %%
places="ooty"
money=2000
if money>=5000:
    print(f" if you go to {places} enjoying the all places.")
elif money>=3000:
    print(f" if you go to {places} but not enjoy the places.")
else:
    print("you are not going to tour")
# Out:
# you are not going to tour

# %%
#nested if (25 country)

# %%
country=input("enter the country:")
if country=="india":
    capital="new delhi"
    print(f"the {country}  capital is{capital}")
elif country=="usa":
    capital="washington"
    print(f"the {country} capital is {capital}")
elif country=="canada":
    capital="ottawa"
    print(f"the {country} capital is {capital}")
elif country=="uk":
    capital="londan"
    print(f"the {country} capital is {capital}")
elif country=="germany":
    capital="berlin"
    print(f"the {country} capital is {capital}")
elif country=="france":
    capital="paris"
    print(f"the {country} capital is {capital}")

else:
    print("the is not available")
# Out:
# enter the country: india
# the india  capital isnew delhi

# %%
country=input("enter the country")
nationality=input("enter your nationality")
age=int(input("enter your age"))
if country=="india":
    if nationality=="indian":
        if age>=18:
            print("you are eligible for indian  citizenship")
        else:
            print("you are not eligible for citizenchip")
elif country=="usa":
    if nationality=="usa":
        if age>5:
            print("you are eligible for usa citizenship")
        else:
            print("you are not eligible")
elif country=="canada":
    if nationality=="canada":
        if age>6:
            print("you are eligible for canada citizenship")
        else:
            print("you are not eligible")  
elif country=="russia":
    if nationality=="russia":
        if age>7:
            print("you are eligible for russia citizenship")
        else:
            print("you are not eligible")
elif country=="brazil":
    if nationality=="brazil":
        if age>8:
            print("you are eligible for brazil citizenship")
        else:
            print("you are not eligible") 
elif country=="australia":
    if nationality=="australia":
        if age>9:
            print("you are eligible for australia citizenship")
        else:
            print("you are not eligible")
elif country=="england":
    if nationality=="england":
        if age>10:
            print("you are eligible for england citizenship")
        else:
            print("you are not eligible")
elif country=="wi":
    if nationality=="wi":
        if age>11:
            print("you are eligible for wi citizenship")
        else:
            print("you are not eligible")
elif country=="new_zealand":
    if nationality=="new_zealand":
        if age>12:
            print("you are eligible for new_land citizenship")
        else:
            print("you are not eligible")
elif country=="pakistan":
    if nationality=="pakistan":
        if age>13:
            print("you are eligible for pakistan citizenship")
        else:
            print("you are not eligible")
elif country=="netharlands":
    if nationality=="netharlands":
        if age>14:
            print("you are eligible for netharlands citizenship")
        else:
            print("you are not eligible")
elif country=="afganistan":
    if nationality=="afganistan":
        if age>15:
            print("you are eligible for afganistan citizenship")
        else:
            print("you are not eligible")
elif country=="ireland":
    if nationality=="ireland":
        if age>16:
            print("you are eligible for ireland citizenship")
        else:
            print("you are not eligible")
elif country=="mexico":
    if nationality=="mexico":
        if age>17:
            print("you are eligible for mexico citizenship")
        else:
            print("you are not eligible")
elif country=="italy":
    if nationality=="italy":
        if age>19:
            print("you are eligible for italy citizenship")
        else:
            print("you are not eligible")
elif country=="spain":
    if nationality=="spain":
        if age>20:
            print("you are eligible for spain citizenship")
        else:
            print("you are not eligible")
elif country=="saudi_arabia":
    if nationality=="saudi_arabia":
        if age>21:
            print("you are eligible for saudi_arabia citizenship")
        else:
            print("you are not eligible")
elif country=="south_korea":
    if nationality=="south_korea":
        if age>22:
            print("you are eligible for south_korea citizenship")
        else:
            print("you are not eligible")
elif country=="turkey":
    if nationality=="turkey":
        if age>23:
            print("you are eligible for turkey citizenship")
        else:
            print("you are not eligible")
elif country=="egypt":
    if nationality=="egypt":
        if age>24:
            print("you are eligible for egypt citizenship")
        else:
            print("you are not eligible")
elif country=="indonesia":
    if nationality=="indonesia":
        if age>25:
            print("you are eligible for indonesia citizenship")
        else:
            print("you are not eligible")
elif country=="france":
    if nationality=="france":
        if age>26:
            print("you are eligible for france citizenship")
        else:
            print("you are not eligible")
elif country=="uk":
    if nationality=="uk":
        if age>27:
            print("you are eligible for uk citizenship")
        else:
            print("you are not eligible")
elif country=="japan":
    if nationality=="japan":
        if age>28:
            print("you are eligible for japan citizenship")
        else:
            print("you are not eligible")
elif country=="germany":
    if nationality=="germany":
        if age>29:
            print("you are eligible for german citizenship")
        else:
            print("you are not eligible")
else:
    print("your are not recognized")
# Out:
# enter the country india
# enter your nationality indian
# enter your age 18
# you are eligible for indian  citizenship
